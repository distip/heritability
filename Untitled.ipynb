# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('spectrum.csv')

# %%
heritabilities = pd.read_csv('H_all.csv')

# %%
data.head()
# Out:
#    Genotype  Rep  Leaf_num       350       351       352       353       354  \
# 0         1    1       2.0  0.127347  0.114354  0.101045  0.101475  0.107497
# 1         1    2       2.0  0.121162  0.122988  0.112401  0.101649  0.112554
# 2         2    1       1.5  0.113189  0.126603  0.126120  0.110537  0.095685
# 3         2    2       2.0  0.108398  0.112435  0.107573  0.096706  0.092696
# 4         4    1       2.0  0.135304  0.123428  0.107437  0.093791  0.087037
#
#         355       356  ...      2491      2492      2493      2494      2495  \
# 0  0.090479  0.073632  ...  0.074209  0.074093  0.073731  0.073122  0.072774
# 1  0.113085  0.119305  ...  0.072651  0.072218  0.071893  0.071624  0.071518
# 2  0.098572  0.101019  ...  0.045457  0.045160  0.044659  0.043533  0.043155
# 3  0.089441  0.095382  ...  0.044278  0.044433  0.044253  0.043939  0.043714
# 4  0.100671  0.119316  ...  0.064662  0.064289  0.064083  0.063794  0.063567
#
# ...

# %%
data = data.loc[data['350'] > 0 , :]

# %%
colnum=len(data.columns)

# %%
plt.plot(data.iloc[ : , 5:colnum].T)
plt.xticks([148, 648, 1148, 1648], ['X500', 'X1000', 'X1500', 'X2000'])
# Out:
# ([<matplotlib.axis.XTick at 0x28eef62ca90>,
# ...
#  [Text(148, 0, 'X500'),
#   Text(648, 0, 'X1000'),
#   Text(1148, 0, 'X1500'),
#   Text(1648, 0, 'X2000')])

# %%
plt.plot(heritabilities)
plt.xticks([150,650,1150,1650], ['X500','X1000','X1500','X2000'])
plt.xlabel("Wavelenghts")
plt.ylabel("Heritability")
# Out:
# Text(0, 0.5, 'Heritability')
